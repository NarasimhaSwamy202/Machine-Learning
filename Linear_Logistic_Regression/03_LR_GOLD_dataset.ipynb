# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data loading
data = pd.read_csv("GOLDdata.csv")

# %% [markdown]
# # Data Exploration

# %%
data.head()
# Out:
#          Date   Price    Open    High     Low
# 0  10/27/2023  1998.5  1995.0  2019.7  1986.4
# 1  10/26/2023  1997.4  1991.2  2003.7  1981.6
# 2  10/25/2023  1994.9  1982.7  1998.6  1973.6
# 3  10/24/2023  1986.1  1984.1  1992.0  1964.6
# 4  10/23/2023  1987.8  1987.7  1994.3  1971.0

# %%
data.tail()
# Out:
#           Date   Price    Open    High     Low
# 3055  1/9/2012  1608.1  1617.7  1624.6  1605.7
# 3056  1/6/2012  1616.8  1622.4  1632.3  1609.0
# 3057  1/5/2012  1620.1  1614.4  1626.8  1597.7
# 3058  1/4/2012  1612.7  1604.9  1619.8  1593.8
# 3059  1/3/2012  1600.5  1571.0  1608.7  1566.8

# %%
data.shape
# Out:
# (3060, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3060 entries, 0 to 3059
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3060 non-null   object
#  1   Price   3060 non-null   float64
#  2   Open    3060 non-null   float64
#  3   High    3060 non-null   float64
#  4   Low     3060 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 119.7+ KB

# %%
data.isnull().sum()
# Out:
# Date     0
# Price    0
# Open     0
# High     0
# Low      0
# dtype: int64

# %%
data.describe()
# Out:
#              Price         Open         High          Low
# count  3060.000000  3060.000000  3060.000000  3060.000000
# mean   1495.362320  1495.655490  1505.799837  1484.662680
# std     275.382207   275.401214   277.467016   272.942997
# min    1049.600000  1051.500000  1062.700000  1045.400000
# 25%    1257.575000  1258.050000  1266.000000  1251.475000
# 50%    1368.350000  1366.900000  1378.450000  1354.100000
# 75%    1762.750000  1762.800000  1773.950000  1750.325000
# max    2069.400000  2076.400000  2089.200000  2049.000000

# %%
# Import label encoder 
from sklearn.preprocessing import LabelEncoder
  
# label_encoder object knows  
# how to understand word labels. 
label_encoder = LabelEncoder() 
  
# Encode labels in column 'species'. 
data['Date']= label_encoder.fit_transform(data['Date']) 
  
data['Date'].unique()
# Out:
# array([428, 420, 411, ..., 215, 206, 179])

# %%
data.head()
# Out:
#    Date   Price    Open    High     Low
# 0   428  1998.5  1995.0  2019.7  1986.4
# 1   420  1997.4  1991.2  2003.7  1981.6
# 2   411  1994.9  1982.7  1998.6  1973.6
# 3   402  1986.1  1984.1  1992.0  1964.6
# 4   393  1987.8  1987.7  1994.3  1971.0

# %%
data.tail()
# Out:
#       Date   Price    Open    High     Low
# 3055   248  1608.1  1617.7  1624.6  1605.7
# 3056   223  1616.8  1622.4  1632.3  1609.0
# 3057   215  1620.1  1614.4  1626.8  1597.7
# 3058   206  1612.7  1604.9  1619.8  1593.8
# 3059   179  1600.5  1571.0  1608.7  1566.8

# %%
for col in data.columns:
    plt.boxplot(data[col])
    plt.xlabel(col)
    plt.show()

# %%
for col in data.columns:
    plt.hist(data[col])
    plt.xlabel(col)
    plt.show()

# %%
x = pd.DataFrame(data[["Date","Open","High","Low"]])
y = pd.DataFrame(data["Price"])

# %%
x
# Out:
#       Date    Open    High     Low
# 0      428  1995.0  2019.7  1986.4
# 1      420  1991.2  2003.7  1981.6
# 2      411  1982.7  1998.6  1973.6
# 3      402  1984.1  1992.0  1964.6
# 4      393  1987.7  1994.3  1971.0
# ...    ...     ...     ...     ...
# 3055   248  1617.7  1624.6  1605.7
# 3056   223  1622.4  1632.3  1609.0
# 3057   215  1614.4  1626.8  1597.7
# 3058   206  1604.9  1619.8  1593.8
# 3059   179  1571.0  1608.7  1566.8
#
# [3060 rows x 4 columns]

# %%
y
# Out:
#        Price
# 0     1998.5
# 1     1997.4
# 2     1994.9
# 3     1986.1
# 4     1987.8
# ...      ...
# 3055  1608.1
# 3056  1616.8
# 3057  1620.1
# 3058  1612.7
# 3059  1600.5
#
# [3060 rows x 1 columns]

# %% [markdown]
# # Split the data into features (X) and target (y) label sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state = 10)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2448, 4)
# (2448, 1)
# (612, 4)
# (612, 1)

# %%
x_train
# Out:
#       Date    Open    High     Low
# 1426  1844  1304.4  1314.9  1304.3
# 739    916  1878.0  1891.3  1875.6
# 2982  1593  1643.2  1648.2  1638.6
# 1837  2958  1340.8  1346.1  1336.5
# 2799   207  1663.8  1664.5  1626.0
# ...    ...     ...     ...     ...
# 2009   157  1119.9  1128.0  1114.9
# 1180  1550  1293.2  1293.5  1285.3
# 1344  2677  1191.6  1215.4  1189.5
# 527    409  1794.2  1811.5  1793.0
# 1289   753  1224.3  1224.6  1207.2
#
# [2448 rows x 4 columns]

# %%
y_train
# Out:
#        Price
# 1426  1305.6
# 739   1882.9
# 2982  1642.8
# 1837  1344.1
# 2799  1648.9
# ...      ...
# 2009  1115.8
# 1180  1291.3
# 1344  1213.3
# 527   1806.8
# 1289  1208.6
#
# [2448 rows x 1 columns]

# %% [raw]
# # Split the data into a training and test set

# %%
x_test
# Out:
#       Date    Open    High     Low
# 2802   935  1655.9  1681.0  1655.9
# 1263   823  1241.5  1252.2  1240.0
# 1041   433  1507.4  1510.8  1492.3
# 2340   310  1233.3  1250.3  1222.0
# 707   1023  1825.4  1831.5  1810.1
# ...    ...     ...     ...     ...
# 94    2123  1961.7  1961.7  1932.4
# 1736  1054  1234.3  1243.7  1233.3
# 649   1984  1787.0  1818.6  1781.8
# 2225  1397  1204.6  1206.6  1192.6
# 929   1685  1635.3  1652.8  1624.4
#
# [612 rows x 4 columns]

# %%
y_test
# Out:
#        Price
# 2802  1675.8
# 1263  1251.8
# 1041  1495.8
# 2340  1244.8
# 707   1823.2
# ...      ...
# 94    1938.9
# 1736  1241.6
# 649   1815.7
# 2225  1200.7
# 929   1645.7
#
# [612 rows x 1 columns]

# %% [markdown]
# # Create and Train the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the test set results

# %%
y_test_pred=model.predict(x_test)
y_test_pred
# Out:
# array([[1675.94388777],
#        [1248.83100374],
#        [1498.58926682],
#        [1237.72509419],
#        [1818.86889133],
#        [1086.18021054],
#        [1829.21834922],
#        [1293.93321435],
#        [1854.15908892],
#        [1568.82584496],
#        [1225.48498997],
#        [1803.99789895],
#        [1609.69097273],
#        [1945.8562791 ],
#        [1965.30656093],
#        [1724.02080852],
#        [1821.27646467],
#        [1198.81285668],
#        [1290.1742963 ],
#        [1809.59584106],
#        [1879.97696308],
#        [1229.24618493],
#        [2010.55200093],
#        [1419.07042599],
#        [1268.8836468 ],
#        [1953.01460594],
#        [1855.05135301],
#        [1814.54905731],
#        [1600.08619265],
#        [1243.87549556],
#        [1988.51042221],
#        [1360.13692689],
#        [1385.17823947],
#        [1347.53593651],
#        [1829.79467528],
#        [1321.19380441],
#        [1512.28913153],
#        [1522.43894643],
# ...

# %%
df = pd.DataFrame(columns=["Actual","Predicted"])
df
# Out:
# Empty DataFrame
# Columns: [Actual, Predicted]
# Index: []

# %%
df["Actual"]= y_test
df["Predicted"]= y_test_pred
df
# Out:
#       Actual    Predicted
# 2802  1675.8  1675.943888
# 1263  1251.8  1248.831004
# 1041  1495.8  1498.589267
# 2340  1244.8  1237.725094
# 707   1823.2  1818.868891
# ...      ...          ...
# 94    1938.9  1939.641667
# 1736  1241.6  1241.032964
# 649   1815.7  1808.181080
# 2225  1200.7  1196.944833
# 929   1645.7  1640.922782
#
# [612 rows x 2 columns]

# %%
from sklearn.metrics import *

# %%
r2_score(y_train_pred,y_test)
# Out:
# 0.9996257439613045

# %% [markdown]
# # Calculating the accuracy

# %%
print("Mean absolute error:", mean_absolute_error(y_test,y_test_pred))
print("Mean squared error:", mean_squared_error(y_test,y_test_pred))
print("Root Mean squared error:", np.sqrt(mean_absolute_error(y_test,y_test_pred)))
print("Mean absolute percentage error:", mean_absolute_percentage_error(y_test, y_test_pred)*100)
# Out:
# Mean absolute error: 3.9110555006944843
# Mean squared error: 28.59379901798482
# Root Mean squared error: 1.9776388701414838
# Mean absolute percentage error: 0.2595287046701476
